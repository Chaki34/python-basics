# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaki34/python-basics/blob/main/set%20practice%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = {}  # empty set is a dictonary

print(type(s))

s = {1,3,2,1,2,3,2,1}
print(type(s))
print(s) # not return duplicate items

# covert list to set

list  = [ 1,23,2,1,3,2,2,3,21,1,1,2,4,"sudh","sudh","rekha"]
print(list) # print duplicate also

print(set(list)) # now converet into set so not show repitive items

s.add(4)
s

s.remove(2)
s
# Out:
# <class 'dict'>
# <class 'set'>
# {1, 2, 3}
# [1, 23, 2, 1, 3, 2, 2, 3, 21, 1, 1, 2, 4, 'sudh', 'sudh', 'rekha']
# {1, 2, 3, 4, 'sudh', 'rekha', 21, 23}
# {1, 3, 4}
