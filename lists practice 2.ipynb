# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaki34/python-basics/blob/main/lists%20practice%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l  = ["101","Debmalya", "CSE", "7.9",(10,20,30)]

print(l)

print(l[0:len(l):2]) # we also perfrom slicing like string  into lits also

no = "M"
new  = list(no)

print(l+ new)

cast = l.append("SC/ST")
print(l)

phone = l.append(8597134533)
print(l)

# task  find types of the all items into the list

for  i  in range (len(l)):
  print(type(l[i]))


# from the cast onlt extract SC

print(l[5][0:2])  # means we also perfrom slicing into inner sitrings that stored into list

# task is extract only first  4 digit of phone no

sliced_num  = str(l[6])[0:4] # extract only 8597
print(sliced_num)


# add another list ito l

sub  = ['cse','ece','eee']

l.append(sub)
print(l)

print(l[len(l)-1][1:3])

# if we need to store a list items individually as the from of individuals

l.extend(["10.2","340.2",44,"SHUT"])

print(l)

# CRUD operations

l.insert(10,"KSSHS")
print(l)

l.insert(11,(19,12,32))
print(l)

print(l.pop())
l

print(l.pop(2)) # pop item from 2th idx

# remove use when weknow the element  menas go with elelemt

l.remove("KSSHS")
l

l.reverse() # that reverse the original list(inplace) , but in case of l[::-1] that return a copy of reverse list
print(l)


l2 = [10,32,422,62,14,1452,632]
l2

l2.sort()
l2

l3 = ["devdd" , "deor", "ewqd", "sdadd","dd","dd"]
l3.sort()
l3

print(l2.index(422))

print(l3.index("devdd"))

l3.count("dd")

n = "demfnf"

print(n.replace("d","b")) # show only copy not change in orginal string
n # not start with b cause  string is immmutable  so it only show copy not change the orginal string
# Out:
# ['101', 'Debmalya', 'CSE', '7.9', (10, 20, 30)]
# ['101', 'CSE', (10, 20, 30)]
# ['101', 'Debmalya', 'CSE', '7.9', (10, 20, 30), 'M']
# ['101', 'Debmalya', 'CSE', '7.9', (10, 20, 30), 'SC/ST']
# ['101', 'Debmalya', 'CSE', '7.9', (10, 20, 30), 'SC/ST', 8597134533]
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'tuple'>
# <class 'str'>
# <class 'int'>
# SC
# 8597
# ['101', 'Debmalya', 'CSE', '7.9', (10, 20, 30), 'SC/ST', 8597134533, ['cse', 'ece', 'eee']]
# ['ece', 'eee']
# ['101', 'Debmalya', 'CSE', '7.9', (10, 20, 30), 'SC/ST', 8597134533, ['cse', 'ece', 'eee'], '10.2', '340.2', 44, 'SHUT']
# ['101', 'Debmalya', 'CSE', '7.9', (10, 20, 30), 'SC/ST', 8597134533, ['cse', 'ece', 'eee'], '10.2', '340.2', 'KSSHS', 44, 'SHUT']
# ['101', 'Debmalya', 'CSE', '7.9', (10, 20, 30), 'SC/ST', 8597134533, ['cse', 'ece', 'eee'], '10.2', '340.2', 'KSSHS', (19, 12, 32), 44, 'SHUT']
# SHUT
# CSE
# ...
