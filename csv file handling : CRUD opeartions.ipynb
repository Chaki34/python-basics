# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaki34/python-basics/blob/main/csv%20file%20handling%20%3A%20CRUD%20opeartions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# csv file handeling

# csv = comma separated values
import csv

csv_Data = [
    ["NAME", "RATING", "SCORE"],
    ["Mr. X", "8.7", "0.80"],
    ["Mr. Y", "8.2", "0.75"],
    ["Mr. Z", "9.1", "0.92"],
    ["John", "7.8", "0.68"],
    ["Alex", "8.5", "0.81"],
    ["David", "9.0", "0.89"],
    ["Mike", "7.5", "0.64"],
    ["Sam", "8.9", "0.86"],
    ["Chris", "8.0", "0.72"],
    ["Robert", "9.3", "0.95"]
]

csv_data2 = [
    ["ID", "NAME", "DEPARTMENT", "AGE", "RATING", "SCORE", "SALARY", "CITY", "EXPERIENCE", "STATUS"],

    [101, "Alice", "CSE", 22, 7.9, 0.70, 45000, "Kolkata", 1.5, "Active"],
    [102, "Bob", "ECE", 23, 8.6, 0.83, 52000, "Delhi", 2.0, "Active"],
    [103, "Charlie", "IT", 24, 9.2, 0.91, 68000, "Bangalore", 3.2, "Active"],
    [104, "Daniel", "ME", 21, 7.6, 0.66, 38000, "Mumbai", 0.8, "Inactive"],
    [105, "Emma", "CSE", 25, 8.8, 0.85, 61000, "Pune", 3.5, "Active"],
    [106, "Frank", "ECE", 22, 8.1, 0.74, 47000, "Chennai", 1.7, "Active"],
    [107, "Grace", "IT", 26, 9.0, 0.88, 72000, "Hyderabad", 4.1, "Active"],
    [108, "Henry", "CE", 23, 7.4, 0.61, 41000, "Kolkata", 1.2, "Inactive"],
    [109, "Ivy", "CSE", 24, 8.4, 0.79, 56000, "Bangalore", 2.6, "Active"],
    [110, "Jack", "ECE", 27, 9.4, 0.96, 85000, "Delhi", 5.0, "Active"],

    [111, "Olivia", "IT", 22, 8.7, 0.82, 59000, "Pune", 2.1, "Active"],
    [112, "Liam", "ME", 25, 7.8, 0.69, 43000, "Mumbai", 2.8, "Inactive"],
    [113, "Sophia", "CSE", 23, 9.1, 0.93, 75000, "Chennai", 3.0, "Active"],
    [114, "Noah", "ECE", 24, 8.3, 0.77, 54000, "Hyderabad", 2.4, "Active"],
    [115, "Mia", "CE", 26, 8.9, 0.86, 63000, "Kolkata", 4.0, "Active"]
]

# file crate and write the data

with open("sample_csv.csv","w") as cf:
  csvw = csv.writer(cf)
  for row in csv_Data:
    csvw.writerow(row)


#  read
with open("sample_csv.csv","r") as f :
  csvr = csv.reader(f)
  for i in csvr:
    print(i)


# append & read data

with open("sample_csv2.csv", "a+", newline="") as f:
    csva = csv.writer(f)
    csvr = csv.reader(f)

    for i in csv_data2:
        csva.writerow(i)

    f.seek(0) # reset pointer

    for i in csvr:
        print(i)
# Out:
# ['NAME', 'RATING', 'SCORE']
# ['Mr. X', '8.7', '0.80']
# ['Mr. Y', '8.2', '0.75']
# ['Mr. Z', '9.1', '0.92']
# ['John', '7.8', '0.68']
# ['Alex', '8.5', '0.81']
# ['David', '9.0', '0.89']
# ['Mike', '7.5', '0.64']
# ['Sam', '8.9', '0.86']
# ['Chris', '8.0', '0.72']
# ['Robert', '9.3', '0.95']
# ['ID', 'NAME', 'DEPARTMENT', 'AGE', 'RATING', 'SCORE', 'SALARY', 'CITY', 'EXPERIENCE', 'STATUS']
# ['101', 'Alice', 'CSE', '22', '7.9', '0.7', '45000', 'Kolkata', '1.5', 'Active']
# ['102', 'Bob', 'ECE', '23', '8.6', '0.83', '52000', 'Delhi', '2.0', 'Active']
# ['103', 'Charlie', 'IT', '24', '9.2', '0.91', '68000', 'Bangalore', '3.2', 'Active']
# ['104', 'Daniel', 'ME', '21', '7.6', '0.66', '38000', 'Mumbai', '0.8', 'Inactive']
# ['105', 'Emma', 'CSE', '25', '8.8', '0.85', '61000', 'Pune', '3.5', 'Active']
# ['106', 'Frank', 'ECE', '22', '8.1', '0.74', '47000', 'Chennai', '1.7', 'Active']
# ['107', 'Grace', 'IT', '26', '9.0', '0.88', '72000', 'Hyderabad', '4.1', 'Active']
# ...
