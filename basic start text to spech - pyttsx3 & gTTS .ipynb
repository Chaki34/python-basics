# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaki34/python-basics/blob/main/basic%20start%20text%20to%20spech%20-%20pyttsx3%20%26%20gTTS%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if u run your local mechine then use it
import pyttsx3



engine = pyttsx3.init()

engine.say("Hello, welcome to Python")
engine.runAndWait()
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install gTTS

# %%
# if u use vertual mechine  use this

from IPython.display import Audio
from gtts import gTTS



#text = "Hello, welcome to Python"
text = "नमस्ते, पायथन में आपका स्वागत है।"

# for choose voice

tts = gTTS(
    text=text,
    lang="hi"
)

tts = gTTS(text=text, lang="en")
tts.save("hello.mp3")

Audio("hello.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
